# %%
import pandas as pd
import numpy as np
import os
import datetime
import xlrd

# %%
# 第一次运行
Date = input("第几周?: ")
Pro = input("输入Project名：")
Date = str(Date)
Pro = str(Pro)
df = pd.read_excel(r'C:\Users\YQIAN5\Desktop\EC\EC_old.xlsx',index = False)
now = str(datetime.datetime.now())

oldIssuer = np.array(['Marie Sjöborg/MSJOBORG/VOLVOCARS','Lars Millsvik/LMILLSVI/VOLVOCARS',
                      'Robert Merens/RMERENS/VOLVOCARS','Martin Kasza/MKASZA/VOLVOCARS',
                      'Bengt-Arne Henning/BHENNING/VOLVOCARS','Åke Gustafsson/AGUSTA22/VOLVOCARS',
                      'Jessica Fahlgren/JFAHLGRE/VOLVOCARS','Christian Schneider/CSCHNEID/VOLVOCARS',
                      'Daniel Emring/DEMRING/VOLVOCARS','Elin Vedin/EVEDIN/VOLVOCARS',
                      'Håkan Salomonsson/HSALOMON/VOLVOCARS','Johan Börjesson/JBORJES5/VOLVOCARS',
                      'Kristian Gasparius/KGASPAR2/VOLVOCARS','Lars Johansson/LJOHAN22/VOLVOCARS',
                      'Mikael Björkestam/MBJORKES/VOLVOCARS','Mikael Haraldsson/MHARALDS/VOLVOCARS',
                      'Per Åslund/PASLUND/VOLVOCARS','Pontus Saukkonen/PSAUKKON/VOLVOCARS',
                      'Elin Sjögren/ESJOGRE3/VOLVOCARS','Henrik Lund/HLUND/VOLVOCARS',
                      'Robin Forsberg/RFORSBER/VOLVOCARS','Emil Brorson/EBRORSON/VOLVOCARS',
                      'Vivi Vo/VVO/VOLVOCARS','My Ngoc Johansson/MNGOCHOA/VOLVOCARS',
                      'Diana Valciukaite/DVALCIUK/VOLVOCARS','Martina Tinglöf/MTINGLOF/VOLVOCARS',
                      'Eva Flood/EBORJESS/VOLVOCARS','Björn Kange/BKANGE/VOLVOCARS',
                      'Jörgen Wollnik/JWOLLNIK/VOLVOCARS','Madeleine Nilsson/MNILSS71/VOLVOCARS',
                      'Chandan Manjunath/CMANJUNA/VOLVOCARS','Emma Kastensson/EOSTHAL1/VOLVOCARS',
                      'Sathyamyla Kanthabhabhajeya/SKANTHAB/VOLVOCARS','Håkan Johansson/HJOHANS7/VOLVOCARS',
                      'Huang Hua/HHUA1/VOLVOCARS','Michael Fritz/MFRITZ4/VOLVOCARS',
                      'CLAES FRENDIUS/CFRENDIU/VOLVOCARS','Katarina Axelsson/KAXELSS9/VOLVOCARS',
                      'Disam Al Ali/DALALI/VOLVOCARS','Amir Alisic/AALISIC1/VOLVOCARS',
                      'Denis Pekic/DPEKIC/VOLVOCARS','Sofia Jonsson/SJONSSON/VOLVOCARS',
                      'Stefan Karlström/SKARLSTR/VOLVOCARS','Peter Larsson/PLARSS32/VOLVOCARS',
                      'Krister Näslund/KNASLUND/VOLVOCARS','Cyril Menon/CMENON/VOLVOCARS',
                      'Ehab El-Ali/EELALI1/VOLVOCARS','Conny Tilander/CTILANDE/VOLVOCARS',
                      'Daniel Svensson/DSVENS10/VOLVOCARS','Denisa Mujasevic/DMUJASEV/VOLVOCARS',
                      'Lina Jansson/LJANSSO7/VOLVOCARS','Johan Hallersbo/JHALLER1/VOLVOCARS',
                      'Erik Gröning/EGRONING/VOLVOCARS','Tomas Forsell/TFORSEL2/VOLVOCARS',
                      'Ann-Sofie Bergfeldt/ABERGFEL/VOLVOCARS','Amir Kurtovic/AKURTOVI/VOLVOCARS',
                      'Andreas Stegrell/AHILLER1/VOLVOCARS','Anette Lundberg/ALUNDBE2/VOLVOCARS',
                      'Rainer Bordi/RBORDI/VOLVOCARS','Sandra Percy/SPERCY/VOLVOCARS',
                      'Peter Engblom/PENGBLOM/VOLVOCARS','Maria Benas/MBENAS/VOLVOCARS',
                      'Gökhan Pala/GPALA/VOLVOCARS','Jan Aagaard/JAAGAARD/VOLVOCARS',
                      'Fredrik Lundström/FLUNDSTR/VOLVOCARS','Camilla Odenjung/CODENJUN/VOLVOCARS',
                      'Peter Timm/PTIMM1/VOLVOCARS','Carl Sundin/CSUNDIN4/VOLVOCARS',
                      'Lena Ström/LLOKHOL3/VOLVOCARS','Erik Sedelius/ESEDELIU/VOLVOCARS',
                      'Anders Olofsson/AOLOFS10/VOLVOCARS','Martin Nyberg/MNYBERG2/VOLVOCARS',
                      'Daniel Lordemyr/DLORDEMY/VOLVOCARS','Ylva Lindin/YLINDIN/VOLVOCARS',
                      'Bayram Kirdis/KBAYRAMA/VOLVOCARS','Simon Hannonsson/SHANNON1/VOLVOCARS', 
                      'Lars Gunnarsson/LGUNNARS/VOLVOCARS','Petra Dohsé/PDOHSE/VOLVOCARS',
                      'David Danielsson/DDANIE85/VOLVOCARS','Björn Granli/BGRANLI/VOLVOCARS',
                      'Björn Remning/BREMNING/VOLVOCARS','Carl Höjer/CHOJER1/VOLVOCARS',
                      'Niklas Carlsson/NCARLSS5/VOLVOCARS','Oscar Olofsson/OOLOFSSO/VOLVOCARS',
                      'Peter Haddemo/PHADDEMO/VOLVOCARS','Ponthus Niemand/PNIEMAND/VOLVOCARS',
                      'Nathalie Josefsson/NJOSEFSS/VOLVOCARS','Kristina Granberg/KGRANBER/VOLVOCARS',
                      'Fanny Johansson/FJOHAN80/VOLVOCARS','Temesgen Weldemariam/TWELDEMA/VOLVOCARS',
                      'Alexander Wahlström/AWAHLST3/VOLVOCARS','Izudin Tankovic/ITANKOVI/VOLVOCARS',
                      'Lisa Sterner/LRYDQUIS/VOLVOCARS','Adam Rosén/AROSEN2/VOLVOCARS',
                      'Alexander Pilström/APIHLSTR/VOLVOCARS','Johan Pettersson/JPETTE36/VOLVOCARS',
                      'Leif Johnsson/LJOHNSS8/VOLVOCARS','Elin Johansson/EJOHAN41/VOLVOCARS',
                      'Jimmy Haryana/JOLSSO28/VOLVOCARS','Nicolas Fernandez/NFERNAN1/VOLVOCARS',
                      'Jerry Carlund/JCARLUN1/VOLVOCARS','Kent Bergebring/KBERGEBR/VOLVOCARS',
                      'Arman Amiri/AAMIRI/VOLVOCARS','Andreas Holmberg/AHOLMBE6/VOLVOCARS',
                      'Karl Lilja Sellergren/KSELLERG/VOLVOCARS','Leif Elovsson/LELOVSS1/VOLVOCARS',
                      'Malin Korneliusson/MKORNEL1/VOLVOCARS','Carl-Johan Guldstrand/CGULDSTR/VOLVOCARS',
                      'Emil Ståhl/EJONSS17/VOLVOCARS','Jeanette Malm/JMALM/VOLVOCARS',
                      'Jonatan Sallén/JSALLEN/VOLVOCARS','Nele Hasic/NHASIC/VOLVOCARS',
                      'Qian Chen/QCHEN6/VOLVOCARS','Joakim Pernstål/JPERNSTA/VOLVOCARS',
                      'Stefan Liljevald/SLILJEWA/VOLVOCARS','Anders Johnsson/AJOHNS99/VOLVOCARS',
                      'Tommy Johansson/TJOHAN93/VOLVOCARS','Mikael Johansson/MJOHAN61/VOLVOCARS',
                      'Thomas Bolmgren/TBOLMGRE/VOLVOCARS','Lisa Wadstedt/LWADSTED/VOLVOCARS',
                      'Christian Schneider/CSCHNEID/VOLVOCARS','Fanny Johansson/FJOHAN80/VOLVOCARS',
                      'Ian Calway/ICALWAY/VOLVOCARS','Joel Lantz/JLANTZ6/VOLVOCARS',
                      'Stefan Almblad/SALMBLAD/VOLVOCARS','Omar Nilsson/ONILSSO3/VOLVOCARS',
                      'Liang Chen/LCHEN103/VOLVOCARS','Jenny Kjellgren/JKJELLG1/VOLVOCARS',
                      'Emelie Jansson/EJANSSO8/VOLVOCARS','Bengt Gustafsson/BGUSTA28/VOLVOCARS',
                      'Lasse Björkman/LBJORKM3/VOLVOCARS','Atra Abolghasemi/AABOLGHA/VOLVOCARS',
                      'Frida Olsson/FOLSSO18/VOLVOCARS','Lucas Keogh/LKEOGH/VOLVOCARS',
                      'Anders Johansson/AJOHAN48/VOLVOCARS'])
# 找出Issuer组中含有oldIssuer的部分project为P519
df_1 = df[df['Project'] == Pro]
df_2 = df_1[df_1.Issuer.isin(oldIssuer)]

# 得到除了oldIssuer剩余的部分
df_rest = df_1.append(df_2).drop_duplicates(keep=False)
df_rest['Function']=pd.Series(' ',index=df_rest.index)
df_rest['correct PII']=pd.Series(' ',index=df_rest.index)
df_rest['Category']=pd.Series(' ',index=df_rest.index)
df_rest['Req HS']=pd.Series(' ',index=df_rest.index)
df_rest['DR']=pd.Series(' ',index=df_rest.index)
df_rest['FAT']=pd.Series(' ',index=df_rest.index)
df_rest['Installation']=pd.Series(' ',index=df_rest.index)
df_rest['Verification before TT']=pd.Series(' ',index=df_rest.index)
df_rest['TT']=pd.Series(' ',index=df_rest.index)
df_rest['PP']=pd.Series(' ',index=df_rest.index)
df_rest['J1']=pd.Series(' ',index=df_rest.index)
df_rest['ICA Readiness']=pd.Series(' ',index=df_rest.index)
df_rest['Comment']=pd.Series(' ',index=df_rest.index)
df_rest.drop(['Equipment type','Link to existing equipment model','Desired deliverytime for cost calculation',
           'Area(Shop , Building)','Work station','Calculation Eq Resp','Motivation',
           'CO','KU','ART/PSS','MSS','Desired install week','Desired Delivery Series',
           'Type bound','Prototype','Handing over routine','Equipment Assigner','Total Calc Cost','VPC Ref Number',
           'Approver','Info to','Internal/External resource','Procured by','Design Eq resp','Design Eq resp Dept',
           'Plant Eq resp','Plant Eq resp Dept','Account no','Cost center','TSU Order no','Final Cost','Currency',
           'External resource Calcost','External resource Costcenter','External resource AccountNo','External resource TSU',
           'Discipline Names','Discipline responsibles','Discipline resp dept','Total Calc Cost','Total Money used','LEQM Update required',
           'RFQ Out = Hand Over step0','Fundings Available (TSU Signed)','Order Date','Design approved','Installation ready to test',
           'First Production use = Hand Over step1','Project End = Hand Over step4 (YYwWW)','Design-FMEA','Process-FMEA',
           'Risk Analysis','Document ID','Main Supplier Name','Maintenance Engineer','Delivery Approved by Issuer',
           'FMEA; Design-Process','Documentations, CE.marking','Year (Calculation period for costs)','Prototype Costs',
           'Total rough cost','Trans 01-02','Trans 03-04','Trans 04-05','Trans 05-06','Trans 06-07','Trans 07-08','Trans 08-09',
           'Attachments','Linked EC'], axis=1, inplace=True) 

# 复制
df_2['Function']=pd.Series(np.random.randn(df_2.shape[0]),index=df_2.index)
df_2['Function']=df_2['Issuer']
df_2['Date_time']=pd.Series(now,index=df_2.index)

#替换并改变源文档的值
df_2['Function'].replace('Marie Sjöborg/MSJOBORG/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Lars Millsvik/LMILLSVI/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Robert Merens/RMERENS/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Martin Kasza/MKASZA/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Bengt-Arne Henning/BHENNING/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Åke Gustafsson/AGUSTA22/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Jessica Fahlgren/JFAHLGRE/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Christian Schneider/CSCHNEID/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Daniel Emring/DEMRING/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Elin Vedin/EVEDIN/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Håkan Salomonsson/HSALOMON/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Johan Börjesson/JBORJES5/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Kristian Gasparius/KGASPAR2/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Lars Johansson/LJOHAN22/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Mikael Björkestam/MBJORKES/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('Mikael Haraldsson/MHARALDS/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Per Åslund/PASLUND/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('Pontus Saukkonen/PSAUKKON/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Elin Sjögren/ESJOGRE3/VOLVOCARS','ICX',inplace=True)
df_2['Function'].replace('Henrik Lund/HLUND/VOLVOCARS','ICX',inplace=True)
df_2['Function'].replace('Robin Forsberg/RFORSBER/VOLVOCARS','ICX',inplace=True) 
df_2['Function'].replace('Emil Brorson/EBRORSON/VOLVOCARS','ICX',inplace=True) 
df_2['Function'].replace('Vivi Vo/VVO/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('My Ngoc Johansson/MNGOCHOA/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Diana Valciukaite/DVALCIUK/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Omar Nilsson/ONILSSO3/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Liang Chen/LCHEN103/VOLVOCARS', 'ICX',inplace=True)

df_2['Function'].replace('Martina Tinglöf/MTINGLOF/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Eva Flood/EBORJESS/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Björn Kange/BKANGE/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Jörgen Wollnik/JWOLLNIK/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Madeleine Nilsson/MNILSS71/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Chandan Manjunath/CMANJUNA/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Emma Kastensson/EOSTHAL1/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Sathyamyla Kanthabhabhajeya/SKANTHAB/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Håkan Johansson/HJOHANS7/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Huang Hua/HHUA1/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Michael Fritz/MFRITZ4/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('CLAES FRENDIUS/CFRENDIU/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Katarina Axelsson/KAXELSS9/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Disam Al Ali/DALALI/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Amir Alisic/AALISIC1/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Denis Pekic/DPEKIC/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Sofia Jonsson/SJONSSON/VOLVOCARS', 'VM&C',inplace=True) 
df_2['Function'].replace('Stefan Karlström/SKARLSTR/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Peter Larsson/PLARSS32/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Krister Näslund/KNASLUND/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Cyril Menon/CMENON/VOLVOCARS', 'VM&C',inplace=True)  
df_2['Function'].replace('Ehab El-Ali/EELALI1/VOLVOCARS', 'VM&C',inplace=True)

df_2['Function'].replace('Conny Tilander/CTILANDE/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Daniel Svensson/DSVENS10/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Denisa Mujasevic/DMUJASEV/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Lina Jansson/LJANSSO7/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Erik Gröning/EGRONING/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Tomas Forsell/TFORSEL2/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Ann-Sofie Bergfeldt/ABERGFEL/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Amir Kurtovic/AKURTOVI/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Andreas Stegrell/AHILLER1/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Anette Lundberg/ALUNDBE2/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Rainer Bordi/RBORDI/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Sandra Percy/SPERCY/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Peter Engblom/PENGBLOM/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Maria Benas/MBENAS/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Gökhan Pala/GPALA/VOLVOCARS', 'Ext',inplace=True)  
df_2['Function'].replace('Jan Aagaard/JAAGAARD/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Fredrik Lundström/FLUNDSTR/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Camilla Odenjung/CODENJUN/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Fanny Johansson/FJOHAN80/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Ian Calway/ICALWAY/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Joel Lantz/JLANTZ6/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Stefan Almblad/SALMBLAD/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Jenny Kjellgren/JKJELLG1/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Emelie Jansson/EJANSSO8/VOLVOCARS', 'Ext',inplace=True)

df_2['Function'].replace('Peter Timm/PTIMM1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Carl Sundin/CSUNDIN4/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lena Ström/LLOKHOL3/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Erik Sedelius/ESEDELIU/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Anders Olofsson/AOLOFS10/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Martin Nyberg/MNYBERG2/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Daniel Lordemyr/DLORDEMY/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Ylva Lindin/YLINDIN/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Bayram Kirdis/KBAYRAMA/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Simon Hannonsson/SHANNON1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lars Gunnarsson/LGUNNARS/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Petra Dohsé/PDOHSE/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('David Danielsson/DDANIE85/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Björn Granli/BGRANLI/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Björn Remning/BREMNING/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Carl Höjer/CHOJER1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Niklas Carlsson/NCARLSS5/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Oscar Olofsson/OOLOFSSO/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Peter Haddemo/PHADDEMO/VOLVOCARS', 'EL HW',inplace=True)  
df_2['Function'].replace('Ponthus Niemand/PNIEMAND/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Nathalie Josefsson/NJOSEFSS/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Kristina Granberg/KGRANBER/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Fanny Johansson/FJOHAN80/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Bengt Gustafsson/BGUSTA28/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lasse Björkman/LBJORKM3/VOLVOCARS', 'EL HW',inplace=True)

df_2['Function'].replace('Temesgen Weldemariam/TWELDEMA/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Alexander Wahlström/AWAHLST3/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Izudin Tankovic/ITANKOVI/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Lisa Sterner/LRYDQUIS/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Adam Rosén/AROSEN2/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Alexander Pilström/APIHLSTR/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Johan Pettersson/JPETTE36/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Leif Johnsson/LJOHNSS8/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Elin Johansson/EJOHAN41/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Jimmy Haryana/JOLSSO28/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Nicolas Fernandez/NFERNAN1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Jerry Carlund/JCARLUN1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Kent Bergebring/KBERGEBR/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Arman Amiri/AAMIRI/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Andreas Holmberg/AHOLMBE6/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Karl Lilja Sellergren/KSELLERG/VOLVOCARS', 'PT',inplace=True)     
df_2['Function'].replace('Leif Elovsson/LELOVSS1/VOLVOCARS', 'PT',inplace=True) 
df_2['Function'].replace('Malin Korneliusson/MKORNEL1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Christian Schneider/CSCHNEID/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Atra Abolghasemi/AABOLGHA/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Frida Olsson/FOLSSO18/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Lucas Keogh/LKEOGH/VOLVOCARS', 'PT',inplace=True)

df_2['Function'].replace('Carl-Johan Guldstrand/CGULDSTR/VOLVOCARS', 'Battery',inplace=True)   
df_2['Function'].replace('Emil Ståhl/EJONSS17/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Jeanette Malm/JMALM/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Jonatan Sallén/JSALLEN/VOLVOCARS', 'Battery',inplace=True)    
df_2['Function'].replace('Nele Hasic/NHASIC/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Qian Chen/QCHEN6/VOLVOCARS', 'Battery',inplace=True)
df_2['Function'].replace('Johan Hallersbo/JHALLER1/VOLVOCARS', 'Battery',inplace=True)

df_2['Function'].replace('Joakim Pernstål/JPERNSTA/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Stefan Liljevald/SLILJEWA/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Anders Johnsson/AJOHNS99/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Tommy Johansson/TJOHAN93/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Mikael Johansson/MJOHAN61/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Thomas Bolmgren/TBOLMGRE/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Lisa Wadstedt/LWADSTED/VOLVOCARS', 'EL SW',inplace=True)
df_2['Function'].replace('Anders Johansson/AJOHAN48/VOLVOCARS', 'EL SW',inplace=True)

df_3 = df_2.fillna(' ')
df_3['correct PII']=pd.Series(' ',index=df_3.index)
df_3['Category']=pd.Series(' ',index=df_3.index)
df_3['Req HS']=pd.Series(' ',index=df_3.index)
df_3['DR']=pd.Series(' ',index=df_3.index)
df_3['FAT']=pd.Series(' ',index=df_3.index)
df_3['Installation']=pd.Series(' ',index=df_3.index)
df_3['Verification before TT']=pd.Series(' ',index=df_3.index)
df_3['TT']=pd.Series(' ',index=df_3.index)
df_3['PP']=pd.Series(' ',index=df_3.index)
df_3['J1']=pd.Series(' ',index=df_3.index)
df_3['ICA Readiness']=pd.Series(' ',index=df_rest.index)
df_3['Comment']=pd.Series(' ',index=df_3.index)
df_3.drop(['Equipment type','Link to existing equipment model','Desired deliverytime for cost calculation',
          'Area(Shop , Building)','Work station','Calculation Eq Resp','Motivation',
           'CO','KU','ART/PSS','MSS','Desired install week','Desired Delivery Series',
           'Type bound','Prototype','Handing over routine','Equipment Assigner','Total Calc Cost','VPC Ref Number',
           'Approver','Info to','Internal/External resource','Procured by','Design Eq resp','Design Eq resp Dept',
           'Plant Eq resp','Plant Eq resp Dept','Account no','Cost center','TSU Order no','Final Cost','Currency',
           'External resource Calcost','External resource Costcenter','External resource AccountNo','External resource TSU',
           'Discipline Names','Discipline responsibles','Discipline resp dept','Total Calc Cost','Total Money used','LEQM Update required',
           'RFQ Out = Hand Over step0','Fundings Available (TSU Signed)','Order Date','Design approved','Installation ready to test',
           'First Production use = Hand Over step1','Project End = Hand Over step4 (YYwWW)','Design-FMEA','Process-FMEA',
           'Risk Analysis','Document ID','Main Supplier Name','Maintenance Engineer','Delivery Approved by Issuer',
           'FMEA; Design-Process','Documentations, CE.marking','Year (Calculation period for costs)','Prototype Costs',
           'Total rough cost','Trans 01-02','Trans 03-04','Trans 04-05','Trans 05-06','Trans 06-07','Trans 07-08','Trans 08-09',
           'Attachments','Linked EC'], axis=1, inplace=True)
# Out:
# 第几周?: 21w28
# 输入Project名：P519
# <ipython-input-39-a78e5139cabc>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Function']=pd.Series(np.random.randn(df_2.shape[0]),index=df_2.index)
# <ipython-input-39-a78e5139cabc>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Function']=df_2['Issuer']
# <ipython-input-39-a78e5139cabc>:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_Ext = df_3[(df_3['Function'] == 'Ext')]
path_Ext = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
df_Ext.to_excel(path_Ext,index = False)

# %%
df_PT = df_3[(df_3['Function'] == 'PT')]
path_PT = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
df_PT.to_excel(path_PT,index = False)

# %%
df_VMC = df_3[(df_3['Function'] == 'VM&C')]
path_VMC = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
df_VMC.to_excel(path_VMC,index = False)

# %%
df_Battery = df_3[(df_3['Function'] == 'Battery')]
path_Battery = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
df_Battery.to_excel(path_Battery,index = False)

# %%
df_ELHW = df_3[(df_3['Function'] == 'EL HW')]
path_ELHW = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
df_ELHW.to_excel(path_ELHW,index = False)

# %%
df_ICX = df_3[(df_3['Function'] == 'ICX')]
path_ICX = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
df_ICX.to_excel(path_ICX,index = False)

# %%
df_ELSW = df_3[(df_3['Function'] == 'EL SW')]
path_ELSW = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
df_ELSW.to_excel(path_ELSW,index = False)

# %%
path_rest = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\rest\\" + "rest_" + Pro + ".xlsx"
df_rest.to_excel(path_rest,index = False)

# %%
#更新
#df_a = pd.read_excel(pathnew)
#df_b = pd.read_excel(pathold)
Date = input("第几周?: ")
Pro = input("输入Project名：")
Date = str(Date)
Pro = str(Pro)
df_b = pd.read_excel(r'C:\Users\YQIAN5\Desktop\EC\EC_old.xlsx',index = False)
df_a = pd.read_excel(r'C:\Users\YQIAN5\Desktop\EC\EC_new.xlsx',index = False)
# Out:
# 第几周?: 21w31
# 输入Project名：723K

# %%
#重新分配(因为Issuer改变，相同的EC可能分到不同的Function team)
Ext = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx",index = False)
PT = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx",index = False)
VMC = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx",index = False)
ELHW = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx",index = False)
ELSW = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx",index = False)
Battery = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx",index = False)
ICX = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx",index = False)

df_new = pd.concat([Ext,PT,VMC,ELHW,ELSW,Battery,ICX], axis = 0, ignore_index = True, join = "outer")

df_Ext = df_new[(df_new['Function'] == 'Ext')]
path_Ext = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
df_Ext.to_excel(path_Ext,index = False)

df_PT = df_new[(df_new['Function'] == 'PT')]
path_PT = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
df_PT.to_excel(path_PT,index = False)

df_VMC = df_new[(df_new['Function'] == 'VM&C')]
path_VMC = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
df_VMC.to_excel(path_VMC,index = False)

df_Battery = df_new[(df_new['Function'] == 'Battery')]
path_Battery = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
df_Battery.to_excel(path_Battery,index = False)

df_ELHW = df_new[(df_new['Function'] == 'EL HW')]
path_ELHW = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
df_ELHW.to_excel(path_ELHW,index = False)

df_ICX = df_new[(df_new['Function'] == 'ICX')]
path_ICX = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
df_ICX.to_excel(path_ICX,index = False)

df_ELSW = df_new[(df_new['Function'] == 'EL SW')]
path_ELSW = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
df_ELSW.to_excel(path_ELSW,index = False)

# %%
# only update sheet
df_c = df_a.append(df_b).drop_duplicates(keep=False,subset = 'EC')

# %%
oldIssuer = np.array(['Marie Sjöborg/MSJOBORG/VOLVOCARS','Lars Millsvik/LMILLSVI/VOLVOCARS',
                      'Robert Merens/RMERENS/VOLVOCARS','Martin Kasza/MKASZA/VOLVOCARS',
                      'Bengt-Arne Henning/BHENNING/VOLVOCARS','Åke Gustafsson/AGUSTA22/VOLVOCARS',
                      'Jessica Fahlgren/JFAHLGRE/VOLVOCARS','Christian Schneider/CSCHNEID/VOLVOCARS',
                      'Daniel Emring/DEMRING/VOLVOCARS','Elin Vedin/EVEDIN/VOLVOCARS',
                      'Håkan Salomonsson/HSALOMON/VOLVOCARS','Johan Börjesson/JBORJES5/VOLVOCARS',
                      'Kristian Gasparius/KGASPAR2/VOLVOCARS','Lars Johansson/LJOHAN22/VOLVOCARS',
                      'Mikael Björkestam/MBJORKES/VOLVOCARS','Mikael Haraldsson/MHARALDS/VOLVOCARS',
                      'Per Åslund/PASLUND/VOLVOCARS','Pontus Saukkonen/PSAUKKON/VOLVOCARS',
                      'Elin Sjögren/ESJOGRE3/VOLVOCARS','Henrik Lund/HLUND/VOLVOCARS',
                      'Robin Forsberg/RFORSBER/VOLVOCARS','Emil Brorson/EBRORSON/VOLVOCARS',
                      'Vivi Vo/VVO/VOLVOCARS','My Ngoc Johansson/MNGOCHOA/VOLVOCARS',
                      'Diana Valciukaite/DVALCIUK/VOLVOCARS','Martina Tinglöf/MTINGLOF/VOLVOCARS',
                      'Eva Flood/EBORJESS/VOLVOCARS','Björn Kange/BKANGE/VOLVOCARS',
                      'Jörgen Wollnik/JWOLLNIK/VOLVOCARS','Madeleine Nilsson/MNILSS71/VOLVOCARS',
                      'Chandan Manjunath/CMANJUNA/VOLVOCARS','Emma Kastensson/EOSTHAL1/VOLVOCARS',
                      'Sathyamyla Kanthabhabhajeya/SKANTHAB/VOLVOCARS','Håkan Johansson/HJOHANS7/VOLVOCARS',
                      'Huang Hua/HHUA1/VOLVOCARS','Michael Fritz/MFRITZ4/VOLVOCARS',
                      'CLAES FRENDIUS/CFRENDIU/VOLVOCARS','Katarina Axelsson/KAXELSS9/VOLVOCARS',
                      'Disam Al Ali/DALALI/VOLVOCARS','Amir Alisic/AALISIC1/VOLVOCARS',
                      'Denis Pekic/DPEKIC/VOLVOCARS','Sofia Jonsson/SJONSSON/VOLVOCARS',
                      'Stefan Karlström/SKARLSTR/VOLVOCARS','Peter Larsson/PLARSS32/VOLVOCARS',
                      'Krister Näslund/KNASLUND/VOLVOCARS','Cyril Menon/CMENON/VOLVOCARS',
                      'Ehab El-Ali/EELALI1/VOLVOCARS','Conny Tilander/CTILANDE/VOLVOCARS',
                      'Daniel Svensson/DSVENS10/VOLVOCARS','Denisa Mujasevic/DMUJASEV/VOLVOCARS',
                      'Lina Jansson/LJANSSO7/VOLVOCARS','Johan Hallersbo/JHALLER1/VOLVOCARS',
                      'Erik Gröning/EGRONING/VOLVOCARS','Tomas Forsell/TFORSEL2/VOLVOCARS',
                      'Ann-Sofie Bergfeldt/ABERGFEL/VOLVOCARS','Amir Kurtovic/AKURTOVI/VOLVOCARS',
                      'Andreas Stegrell/AHILLER1/VOLVOCARS','Anette Lundberg/ALUNDBE2/VOLVOCARS',
                      'Rainer Bordi/RBORDI/VOLVOCARS','Sandra Percy/SPERCY/VOLVOCARS',
                      'Peter Engblom/PENGBLOM/VOLVOCARS','Maria Benas/MBENAS/VOLVOCARS',
                      'Gökhan Pala/GPALA/VOLVOCARS','Jan Aagaard/JAAGAARD/VOLVOCARS',
                      'Fredrik Lundström/FLUNDSTR/VOLVOCARS','Camilla Odenjung/CODENJUN/VOLVOCARS',
                      'Peter Timm/PTIMM1/VOLVOCARS','Carl Sundin/CSUNDIN4/VOLVOCARS',
                      'Lena Ström/LLOKHOL3/VOLVOCARS','Erik Sedelius/ESEDELIU/VOLVOCARS',
                      'Anders Olofsson/AOLOFS10/VOLVOCARS','Martin Nyberg/MNYBERG2/VOLVOCARS',
                      'Daniel Lordemyr/DLORDEMY/VOLVOCARS','Ylva Lindin/YLINDIN/VOLVOCARS',
                      'Bayram Kirdis/KBAYRAMA/VOLVOCARS','Simon Hannonsson/SHANNON1/VOLVOCARS', 
                      'Lars Gunnarsson/LGUNNARS/VOLVOCARS','Petra Dohsé/PDOHSE/VOLVOCARS',
                      'David Danielsson/DDANIE85/VOLVOCARS','Björn Granli/BGRANLI/VOLVOCARS',
                      'Björn Remning/BREMNING/VOLVOCARS','Carl Höjer/CHOJER1/VOLVOCARS',
                      'Niklas Carlsson/NCARLSS5/VOLVOCARS','Oscar Olofsson/OOLOFSSO/VOLVOCARS',
                      'Peter Haddemo/PHADDEMO/VOLVOCARS','Ponthus Niemand/PNIEMAND/VOLVOCARS',
                      'Nathalie Josefsson/NJOSEFSS/VOLVOCARS','Kristina Granberg/KGRANBER/VOLVOCARS',
                      'Fanny Johansson/FJOHAN80/VOLVOCARS','Temesgen Weldemariam/TWELDEMA/VOLVOCARS',
                      'Alexander Wahlström/AWAHLST3/VOLVOCARS','Izudin Tankovic/ITANKOVI/VOLVOCARS',
                      'Lisa Sterner/LRYDQUIS/VOLVOCARS','Adam Rosén/AROSEN2/VOLVOCARS',
                      'Alexander Pilström/APIHLSTR/VOLVOCARS','Johan Pettersson/JPETTE36/VOLVOCARS',
                      'Leif Johnsson/LJOHNSS8/VOLVOCARS','Elin Johansson/EJOHAN41/VOLVOCARS',
                      'Jimmy Haryana/JOLSSO28/VOLVOCARS','Nicolas Fernandez/NFERNAN1/VOLVOCARS',
                      'Jerry Carlund/JCARLUN1/VOLVOCARS','Kent Bergebring/KBERGEBR/VOLVOCARS',
                      'Arman Amiri/AAMIRI/VOLVOCARS','Andreas Holmberg/AHOLMBE6/VOLVOCARS',
                      'Karl Lilja Sellergren/KSELLERG/VOLVOCARS','Leif Elovsson/LELOVSS1/VOLVOCARS',
                      'Malin Korneliusson/MKORNEL1/VOLVOCARS','Carl-Johan Guldstrand/CGULDSTR/VOLVOCARS',
                      'Emil Ståhl/EJONSS17/VOLVOCARS','Jeanette Malm/JMALM/VOLVOCARS',
                      'Jonatan Sallén/JSALLEN/VOLVOCARS','Nele Hasic/NHASIC/VOLVOCARS',
                      'Qian Chen/QCHEN6/VOLVOCARS','Joakim Pernstål/JPERNSTA/VOLVOCARS',
                      'Stefan Liljevald/SLILJEWA/VOLVOCARS','Anders Johnsson/AJOHNS99/VOLVOCARS',
                      'Tommy Johansson/TJOHAN93/VOLVOCARS','Mikael Johansson/MJOHAN61/VOLVOCARS',
                      'Thomas Bolmgren/TBOLMGRE/VOLVOCARS','Lisa Wadstedt/LWADSTED/VOLVOCARS',
                      'Christian Schneider/CSCHNEID/VOLVOCARS','Fanny Johansson/FJOHAN80/VOLVOCARS',
                      'Ian Calway/ICALWAY/VOLVOCARS','Joel Lantz/JLANTZ6/VOLVOCARS',
                      'Stefan Almblad/SALMBLAD/VOLVOCARS','Omar Nilsson/ONILSSO3/VOLVOCARS',
                      'Liang Chen/LCHEN103/VOLVOCARS','Jenny Kjellgren/JKJELLG1/VOLVOCARS',
                      'Emelie Jansson/EJANSSO8/VOLVOCARS','Bengt Gustafsson/BGUSTA28/VOLVOCARS',
                      'Lasse Björkman/LBJORKM3/VOLVOCARS','Atra Abolghasemi/AABOLGHA/VOLVOCARS',
                      'Frida Olsson/FOLSSO18/VOLVOCARS','Lucas Keogh/LKEOGH/VOLVOCARS',
                      'Anders Johansson/AJOHAN48/VOLVOCARS'])

# %%
# add new Issuer
Ask = input("是否有新增的Issuer?:")
if Ask == 'yes':
    I = input("请输入新增的Issuer:")
    F = input("请输入新增的Issuer的Function:")
    F = str(F)
    I = str(I)
    I = np.array(I)
    newIssuer = np.append(oldIssuer,I)
    
    # 找出Issuer组中含有oldIssuer的部分project为Pro
    df_1 = df_c[df_c['Project'] == Pro]
    df_2 = df_1[df_1.Issuer.isin(newIssuer)]  # 将后面的df_1改为df_2
    
    # 只选取有关的Issuer
    #df_1 = df_c[df_c.Issuer.isin(newIssuer)]
    
    # 得到除了oldIssuer剩余的部分
    df_rest = df_1.append(df_2).drop_duplicates(keep=False)   # df_c改为df_1,df_1改为df_2
    df_rest['Function']=pd.Series(' ',index=df_rest.index)
    df_rest['PII']=pd.Series(' ',index=df_rest.index)
    df_rest['Catergory']=pd.Series(' ',index=df_rest.index)
    df_rest['Req HS']=pd.Series(' ',index=df_rest.index)
    df_rest['DR']=pd.Series(' ',index=df_rest.index)
    df_rest['FAT']=pd.Series(' ',index=df_rest.index)
    df_rest['Installation']=pd.Series(' ',index=df_rest.index)
    df_rest['Verification before TT']=pd.Series(' ',index=df_rest.index)
    df_rest['TT']=pd.Series(' ',index=df_rest.index)
    df_rest['PP']=pd.Series(' ',index=df_rest.index)
    df_rest['J1']=pd.Series(' ',index=df_rest.index)
    df_rest['ICA Readiness']=pd.Series(' ',index=df_rest.index)
    df_rest['Comment']=pd.Series(' ',index=df_rest.index)
    df_rest.drop(['Equipment type','Link to existing equipment model','Desired deliverytime for cost calculation',
           'Area(Shop , Building)','Work station','Calculation Eq Resp','Motivation',
           'CO','KU','ART/PSS','MSS','Desired install week','Desired Delivery Series',
           'Type bound','Prototype','Handing over routine','Equipment Assigner','Total Calc Cost','VPC Ref Number','Linked EC',
           'Approver','Info to','Internal/External resource','Procured by','Design Eq resp','Design Eq resp Dept',
           'Plant Eq resp','Plant Eq resp Dept','Account no','Cost center','TSU Order no','Final Cost','Currency',
           'External resource Calcost','External resource Costcenter','External resource AccountNo','External resource TSU',
           'Discipline Names','Discipline responsibles','Discipline resp dept','Total Calc Cost','Total Money used','LEQM Update required',
           'RFQ Out = Hand Over step0','Fundings Available (TSU Signed)','Order Date','Design approved','Installation ready to test',
           'First Production use = Hand Over step1','Project End = Hand Over step4 (YYwWW)','Design-FMEA','Process-FMEA',
           'Risk Analysis','Document ID','Main Supplier Name','Maintenance Engineer','Delivery Approved by Issuer',
           'FMEA; Design-Process','Documentations, CE.marking','Year (Calculation period for costs)','Prototype Costs',
           'Total rough cost','Trans 01-02','Trans 03-04','Trans 04-05','Trans 05-06','Trans 06-07','Trans 07-08','Trans 08-09',
           'Attachments'], axis=1, inplace=True)
    path_rest = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop\\" + Pro + "08. EC" + "\\rest\\" + "rest" + ".xlsx"
    df_rest.to_excel(path_rest,index = False)
    # 复制
    df_2['Function']=pd.Series(np.random.randn(df_2.shape[0]),index=df_2.index)
    df_2['Function']=df_2['Issuer']
    now = str(datetime.datetime.now())
    df_2['Date_time']=pd.Series(now,index=df_2.index)
    # 替换Function
    df_2['Function'].replace(I,F,inplace = True)
else:
    # 找出Issuer组中含有oldIssuer的部分project为P519
    df_1 = df_c[df_c['Project'] == Pro]
    df_2 = df_1[df_1.Issuer.isin(oldIssuer)]  #将后面的df_1改为df_2
    
    # 只选取有关的Issuer
    #df_1 = df_c[df_c.Issuer.isin(oldIssuer)]
    df_rest = df_1.append(df_2).drop_duplicates(keep=False)   # df_c改为df_1,df_1改为df_2
    df_rest['Function']=pd.Series(' ',index=df_rest.index)
    df_rest['correct PII']=pd.Series(' ',index=df_rest.index)
    df_rest['Category']=pd.Series(' ',index=df_rest.index)
    df_rest['Req HS']=pd.Series(' ',index=df_rest.index)
    df_rest['DR']=pd.Series(' ',index=df_rest.index)
    df_rest['FAT']=pd.Series(' ',index=df_rest.index)
    df_rest['Installation']=pd.Series(' ',index=df_rest.index)
    df_rest['Verification before TT']=pd.Series(' ',index=df_rest.index)
    df_rest['TT']=pd.Series(' ',index=df_rest.index)
    df_rest['PP']=pd.Series(' ',index=df_rest.index)
    df_rest['J1']=pd.Series(' ',index=df_rest.index)
    df_rest['ICA Readiness']=pd.Series(' ',index=df_rest.index)
    df_rest['Comment']=pd.Series(' ',index=df_rest.index)
    df_rest.drop(['Equipment type','Link to existing equipment model','Desired deliverytime for cost calculation',
          'Area(Shop , Building)','Work station','Calculation Eq Resp','Motivation',
           'CO','KU','ART/PSS','MSS','Desired install week','Desired Delivery Series',
           'Type bound','Prototype','Handing over routine','Equipment Assigner','Total Calc Cost','VPC Ref Number','Linked EC',
           'Approver','Info to','Internal/External resource','Procured by','Design Eq resp','Design Eq resp Dept',
           'Plant Eq resp','Plant Eq resp Dept','Account no','Cost center','TSU Order no','Final Cost','Currency',
           'External resource Calcost','External resource Costcenter','External resource AccountNo','External resource TSU',
           'Discipline Names','Discipline responsibles','Discipline resp dept','Total Calc Cost','Total Money used','LEQM Update required',
           'RFQ Out = Hand Over step0','Fundings Available (TSU Signed)','Order Date','Design approved','Installation ready to test',
           'First Production use = Hand Over step1','Project End = Hand Over step4 (YYwWW)','Design-FMEA','Process-FMEA',
           'Risk Analysis','Document ID','Main Supplier Name','Maintenance Engineer','Delivery Approved by Issuer',
           'FMEA; Design-Process','Documentations, CE.marking','Year (Calculation period for costs)','Prototype Costs',
           'Total rough cost','Trans 01-02','Trans 03-04','Trans 04-05','Trans 05-06','Trans 06-07','Trans 07-08','Trans 08-09',
           'Attachments'], axis=1, inplace=True)
    # 复制
    df_2['Function']=pd.Series(np.random.randn(df_2.shape[0]),index=df_2.index)
    df_2['Function']=df_2['Issuer']  
    now = str(datetime.datetime.now())
    df_2['Date_time']=pd.Series(now,index=df_2.index)
# Out:
# 是否有新增的Issuer?:no

# %%
#替换并改变源文档的值
df_2['Function'].replace('Marie Sjöborg/MSJOBORG/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Lars Millsvik/LMILLSVI/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Robert Merens/RMERENS/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Martin Kasza/MKASZA/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Bengt-Arne Henning/BHENNING/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Åke Gustafsson/AGUSTA22/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Jessica Fahlgren/JFAHLGRE/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Christian Schneider/CSCHNEID/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Daniel Emring/DEMRING/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Elin Vedin/EVEDIN/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Håkan Salomonsson/HSALOMON/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Johan Börjesson/JBORJES5/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Kristian Gasparius/KGASPAR2/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Lars Johansson/LJOHAN22/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Mikael Björkestam/MBJORKES/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('Mikael Haraldsson/MHARALDS/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Per Åslund/PASLUND/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('Pontus Saukkonen/PSAUKKON/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Elin Sjögren/ESJOGRE3/VOLVOCARS','ICX',inplace=True)
df_2['Function'].replace('Henrik Lund/HLUND/VOLVOCARS','ICX',inplace=True)
df_2['Function'].replace('Robin Forsberg/RFORSBER/VOLVOCARS','ICX',inplace=True) 
df_2['Function'].replace('Emil Brorson/EBRORSON/VOLVOCARS','ICX',inplace=True) 
df_2['Function'].replace('Vivi Vo/VVO/VOLVOCARS', 'ICX',inplace=True) 
df_2['Function'].replace('My Ngoc Johansson/MNGOCHOA/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Diana Valciukaite/DVALCIUK/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Omar Nilsson/ONILSSO3/VOLVOCARS', 'ICX',inplace=True)
df_2['Function'].replace('Liang Chen/LCHEN103/VOLVOCARS', 'ICX',inplace=True)

df_2['Function'].replace('Martina Tinglöf/MTINGLOF/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Eva Flood/EBORJESS/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Björn Kange/BKANGE/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Jörgen Wollnik/JWOLLNIK/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Madeleine Nilsson/MNILSS71/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Chandan Manjunath/CMANJUNA/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Emma Kastensson/EOSTHAL1/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Sathyamyla Kanthabhabhajeya/SKANTHAB/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Håkan Johansson/HJOHANS7/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Huang Hua/HHUA1/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('Michael Fritz/MFRITZ4/VOLVOCARS','VM&C',inplace=True)
df_2['Function'].replace('CLAES FRENDIUS/CFRENDIU/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Katarina Axelsson/KAXELSS9/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Disam Al Ali/DALALI/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Amir Alisic/AALISIC1/VOLVOCARS','VM&C',inplace=True) 
df_2['Function'].replace('Denis Pekic/DPEKIC/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Sofia Jonsson/SJONSSON/VOLVOCARS', 'VM&C',inplace=True) 
df_2['Function'].replace('Stefan Karlström/SKARLSTR/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Peter Larsson/PLARSS32/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Krister Näslund/KNASLUND/VOLVOCARS', 'VM&C',inplace=True)
df_2['Function'].replace('Cyril Menon/CMENON/VOLVOCARS', 'VM&C',inplace=True)  
df_2['Function'].replace('Ehab El-Ali/EELALI1/VOLVOCARS', 'VM&C',inplace=True)

df_2['Function'].replace('Conny Tilander/CTILANDE/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Daniel Svensson/DSVENS10/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Denisa Mujasevic/DMUJASEV/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Lina Jansson/LJANSSO7/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Erik Gröning/EGRONING/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Tomas Forsell/TFORSEL2/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Ann-Sofie Bergfeldt/ABERGFEL/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Amir Kurtovic/AKURTOVI/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Andreas Stegrell/AHILLER1/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Anette Lundberg/ALUNDBE2/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Rainer Bordi/RBORDI/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Sandra Percy/SPERCY/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Peter Engblom/PENGBLOM/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Maria Benas/MBENAS/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Gökhan Pala/GPALA/VOLVOCARS', 'Ext',inplace=True)  
df_2['Function'].replace('Jan Aagaard/JAAGAARD/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Fredrik Lundström/FLUNDSTR/VOLVOCARS', 'Ext',inplace=True) 
df_2['Function'].replace('Camilla Odenjung/CODENJUN/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Fanny Johansson/FJOHAN80/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Ian Calway/ICALWAY/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Joel Lantz/JLANTZ6/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Stefan Almblad/SALMBLAD/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Jenny Kjellgren/JKJELLG1/VOLVOCARS', 'Ext',inplace=True)
df_2['Function'].replace('Emelie Jansson/EJANSSO8/VOLVOCARS', 'Ext',inplace=True)

df_2['Function'].replace('Peter Timm/PTIMM1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Carl Sundin/CSUNDIN4/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lena Ström/LLOKHOL3/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Erik Sedelius/ESEDELIU/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Anders Olofsson/AOLOFS10/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Martin Nyberg/MNYBERG2/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Daniel Lordemyr/DLORDEMY/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Ylva Lindin/YLINDIN/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Bayram Kirdis/KBAYRAMA/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Simon Hannonsson/SHANNON1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lars Gunnarsson/LGUNNARS/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Petra Dohsé/PDOHSE/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('David Danielsson/DDANIE85/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Björn Granli/BGRANLI/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Björn Remning/BREMNING/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Carl Höjer/CHOJER1/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Niklas Carlsson/NCARLSS5/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Oscar Olofsson/OOLOFSSO/VOLVOCARS', 'EL HW',inplace=True) 
df_2['Function'].replace('Peter Haddemo/PHADDEMO/VOLVOCARS', 'EL HW',inplace=True)  
df_2['Function'].replace('Ponthus Niemand/PNIEMAND/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Nathalie Josefsson/NJOSEFSS/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Kristina Granberg/KGRANBER/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Fanny Johansson/FJOHAN80/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Bengt Gustafsson/BGUSTA28/VOLVOCARS', 'EL HW',inplace=True)
df_2['Function'].replace('Lasse Björkman/LBJORKM3/VOLVOCARS', 'EL HW',inplace=True)

df_2['Function'].replace('Temesgen Weldemariam/TWELDEMA/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Alexander Wahlström/AWAHLST3/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Izudin Tankovic/ITANKOVI/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Lisa Sterner/LRYDQUIS/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Adam Rosén/AROSEN2/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Alexander Pilström/APIHLSTR/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Johan Pettersson/JPETTE36/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Leif Johnsson/LJOHNSS8/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Elin Johansson/EJOHAN41/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Jimmy Haryana/JOLSSO28/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Nicolas Fernandez/NFERNAN1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Jerry Carlund/JCARLUN1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Kent Bergebring/KBERGEBR/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Arman Amiri/AAMIRI/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Andreas Holmberg/AHOLMBE6/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Karl Lilja Sellergren/KSELLERG/VOLVOCARS', 'PT',inplace=True)     
df_2['Function'].replace('Leif Elovsson/LELOVSS1/VOLVOCARS', 'PT',inplace=True) 
df_2['Function'].replace('Malin Korneliusson/MKORNEL1/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Christian Schneider/CSCHNEID/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Atra Abolghasemi/AABOLGHA/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Frida Olsson/FOLSSO18/VOLVOCARS', 'PT',inplace=True)
df_2['Function'].replace('Lucas Keogh/LKEOGH/VOLVOCARS', 'PT',inplace=True)

df_2['Function'].replace('Carl-Johan Guldstrand/CGULDSTR/VOLVOCARS', 'Battery',inplace=True)   
df_2['Function'].replace('Emil Ståhl/EJONSS17/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Jeanette Malm/JMALM/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Jonatan Sallén/JSALLEN/VOLVOCARS', 'Battery',inplace=True)    
df_2['Function'].replace('Nele Hasic/NHASIC/VOLVOCARS', 'Battery',inplace=True)  
df_2['Function'].replace('Qian Chen/QCHEN6/VOLVOCARS', 'Battery',inplace=True)
df_2['Function'].replace('Johan Hallersbo/JHALLER1/VOLVOCARS', 'Battery',inplace=True)

df_2['Function'].replace('Joakim Pernstål/JPERNSTA/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Stefan Liljevald/SLILJEWA/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Anders Johnsson/AJOHNS99/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Tommy Johansson/TJOHAN93/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Mikael Johansson/MJOHAN61/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Thomas Bolmgren/TBOLMGRE/VOLVOCARS', 'EL SW',inplace=True) 
df_2['Function'].replace('Lisa Wadstedt/LWADSTED/VOLVOCARS', 'EL SW',inplace=True) # df_1改为df_2
df_2['Function'].replace('Anders Johansson/AJOHAN48/VOLVOCARS', 'EL SW',inplace=True)
# Out:
# Series([], Name: Function, dtype: object)

# %%
df_3 = df_2.fillna(' ')   # df_2改为df_3

# %%
df_3['correct PII']=pd.Series(' ',index=df_3.index)
df_3['Category']=pd.Series(' ',index=df_3.index)
df_3['Req HS']=pd.Series(' ',index=df_3.index)
df_3['DR']=pd.Series(' ',index=df_3.index)
df_3['FAT']=pd.Series(' ',index=df_3.index)
df_3['Installation']=pd.Series(' ',index=df_3.index)
df_3['Verification before TT']=pd.Series(' ',index=df_3.index)
df_3['TT']=pd.Series(' ',index=df_3.index)
df_3['PP']=pd.Series(' ',index=df_3.index)
df_3['J1']=pd.Series(' ',index=df_3.index)
df_3['ICA Readiness']=pd.Series(' ',index=df_rest.index)
df_3['Comment']=pd.Series(' ',index=df_3.index)
df_3.drop(['Equipment type','Link to existing equipment model','Desired deliverytime for cost calculation',
          'Area(Shop , Building)','Work station','Calculation Eq Resp','Motivation',
           'CO','KU','ART/PSS','MSS','Desired install week','Desired Delivery Series',
           'Type bound','Prototype','Handing over routine','Equipment Assigner','Total Calc Cost','VPC Ref Number','Linked EC',
           'Approver','Info to','Internal/External resource','Procured by','Design Eq resp','Design Eq resp Dept',
           'Plant Eq resp','Plant Eq resp Dept','Account no','Cost center','TSU Order no','Final Cost','Currency',
           'External resource Calcost','External resource Costcenter','External resource AccountNo','External resource TSU',
           'Discipline Names','Discipline responsibles','Discipline resp dept','Total Calc Cost','Total Money used','LEQM Update required',
           'RFQ Out = Hand Over step0','Fundings Available (TSU Signed)','Order Date','Design approved','Installation ready to test',
           'First Production use = Hand Over step1','Project End = Hand Over step4 (YYwWW)','Design-FMEA','Process-FMEA',
           'Risk Analysis','Document ID','Main Supplier Name','Maintenance Engineer','Delivery Approved by Issuer',
           'FMEA; Design-Process','Documentations, CE.marking','Year (Calculation period for costs)','Prototype Costs',
           'Total rough cost','Trans 01-02','Trans 03-04','Trans 04-05','Trans 05-06','Trans 06-07','Trans 07-08','Trans 08-09',
           'Attachments'], axis=1, inplace=True)

# %%
# rest update
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\rest\\" + "rest_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

dfnew = pd.concat([old,df_rest], axis = 0, ignore_index = True, join = "outer")

# 获取想要highlight的行
light = []
for i in dfnew.index: 
    if i > Nrowold-1: 
        light.append(i) 

def highlight(x):  
    return ['background-color: yellow'for i in x]
    
dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_old,index = False)

# %%
df_Ext = df_3[(df_3['Function'] == 'Ext')]
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "Ext\\" + str(j) + ".xlsx",index = False)
        m = m+1
        
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
    path_Extbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Ext_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_Ext], axis = 0, ignore_index = True, join = "outer")
    #dfnew['Workflow position']= data_Ext
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_Extbackup = dfnew
    #df_Extbackup = pd.concat([old,df_Ext], axis = 0, ignore_index = True, join = "outer")
    #df_Extbackup['Workflow position']= data_Ext
    df_Extbackup.to_excel(path_Extbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)
    
    #path = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\sheet\\" + "\\Ext" #指定文件夹路径
    #wj_List = list(os.walk(path))[0][2]       #所有子文件名
    #num = len(wj_List)                        #子文件名的个数
    
    #m = num 
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\Ext\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
        path_Extbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Ext_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_Extbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        #del df1['Unnamed: 0']
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_Ext = df_3[(df_3['Function'] == 'Ext')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_Ext], axis = 0, ignore_index = True, join = "outer")
    print(dfnew.index)
    #dfnew['Workflow position']= data_Ext
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_Extbackup = dfnew
    #df_Extbackup = pd.concat([old,df_Ext], axis = 0, ignore_index = True, join = "outer")
    #df_Extbackup['Workflow position']= data_Ext
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Ext\\" + "Ext_" + Pro + ".xlsx"
    path_Extbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Ext_" + Pro + Date + ".xlsx"
    
    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False) 
    df_Extbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_Extbackup,index = False)

# %%
df_VMC = df_3[(df_3['Function'] == 'VM&C')]
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "\\sheet\\" + "VM&C\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
    path_VMCbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "VM&C_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_VMC], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_VMCbackup = dfnew
    #df_VMCbackup = pd.concat([old,df_VMC], axis = 0, ignore_index = True, join = "outer")
    df_VMCbackup.to_excel(path_VMCbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)
    
    #m = num 
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1   
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\VM&C\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
        
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
        path_VMCbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "VM&C_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_VMCbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_VMC = df_3[(df_3['Function'] == 'VM&C')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_VMC], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_VMCbackup = dfnew
    #df_VMCbackup = pd.concat([old,df_VMC], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\VM&C\\" + "VM&C_" + Pro + ".xlsx"
    path_VMCbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "VM&C_" + Pro + Date + ".xlsx"

    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_VMCbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_VMCbackup,index = False)

# %%
df_PT = df_3[(df_3['Function'] == 'PT')]
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "PT\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
    path_PTbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "PT_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_PT], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_PTbackup = dfnew
    #df_PTbackup = pd.concat([old,df_PT], axis = 0, ignore_index = True, join = "outer")
    df_PTbackup.to_excel(path_PTbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)
    
    #m = num - 1
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1  
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet" + "\\PT\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
        path_PTbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "PT_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_PTbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_PT = df_3[(df_3['Function'] == 'PT')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_PT], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_PTbackup = dfnew
    #df_PTbackup = pd.concat([old,df_PT], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\PT\\" + "PT_" + Pro + ".xlsx"
    path_PTbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "PT_" + Pro + Date + ".xlsx"

    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_PTbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_PTbackup,index = False)

# %%
df_ELHW = df_3[(df_3['Function'] == 'EL HW')]
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "ELHW\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
    path_ELHWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELHW_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_ELHW], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ELHWbackup = dfnew
    #df_ELHWbackup = pd.concat([old,df_ELHW], axis = 0, ignore_index = True, join = "outer")
    df_ELHWbackup.to_excel(path_ELHWbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)

    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELHW\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
        path_ELHWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELHW_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_ELHWbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_ELHW = df_3[(df_3['Function'] == 'EL HW')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_ELHW], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ELHWbackup = dfnew
    #df_ELHWbackup = pd.concat([old,df_ELHW], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELHW\\" + "ELHW_" + Pro + ".xlsx"
    path_ELHWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELHW_" + Pro + Date + ".xlsx"
    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_ELHWbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_ELHWbackup,index = False)

# %%
df_Battery = df_3[(df_3['Function'] == 'Battery')]
path_old = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "Battery\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
    path_Batterybackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Battery_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_Battery], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_Batterybackup = dfnew
    #df_Batterybackup = pd.concat([old,df_Battery], axis = 0, ignore_index = True, join = "outer")
    df_Batterybackup.to_excel(path_Batterybackup,index = False)
    dfnew.to_excel(pathupdate,index = False)

    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\Battery\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
        path_Batterybackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Battery_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_Batterybackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_Battery = df_3[(df_3['Function'] == 'Battery')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_Battery], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_Batterybackup = dfnew
    #df_Batterybackup = pd.concat([old,df_Battery], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\Battery\\" + "Battery_" + Pro + ".xlsx"
    path_Batterybackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "Battery_" + Pro + Date + ".xlsx"
    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_Batterybackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_Batterybackup,index = False)

# %%
df_ICX = df_3[(df_3['Function'] == 'ICX')]
path_old =  r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "ICX\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
    path_ICXbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ICX_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_ICX], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ICXbackup = dfnew
    #df_ICXbackup = pd.concat([old,df_ICX], axis = 0, ignore_index = True, join = "outer")
    df_ICXbackup.to_excel(path_ICXbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)
    
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ICX\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
        path_ICXbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ICX_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_ICXbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_ICX = df_3[(df_3['Function'] == 'ICX')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_ICX], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ICXbackup = dfnew
    #df_ICXbackup = pd.concat([old,df_ICX], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ICX\\" + "ICX_" + Pro + ".xlsx"
    path_ICXbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ICX_" + Pro + Date + ".xlsx"
    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_ICXbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_ICXbackup,index = False)

# %%
df_ELSW = df_3[(df_3['Function'] == 'EL SW')]
path_old =  r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
old = pd.read_excel(path_old,index = False)

Nrowold = old.shape[0]
Book1Allsheet = pd.read_excel(path_old,sheet_name=None)
#print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
m = 0
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        #del sheetcon['index']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup" + "\\sheet\\" + "ELSW\\" + str(j) + ".xlsx",index = False)
        m = m+1
    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
    path_ELSWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELSW_" + Pro + Date + ".xlsx"
    dfnew = pd.concat([old,df_ELSW], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ELSWbackup = dfnew
    #df_ELSWbackup = pd.concat([old,df_ELSW], axis = 0, ignore_index = True, join = "outer")
    df_ELSWbackup.to_excel(path_ELSWbackup,index = False)
    dfnew.to_excel(pathupdate,index = False)
    
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "0.xlsx",index = False)
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "1.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "2.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "3.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "4.xlsx",index = False)
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "5.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df7 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "6.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df8 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "7.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df9 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "8.xlsx",index = False)
        m = m-1
        n = n+1
    if m>0:
        df10 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\backup" + "\\sheet" + "\\ELSW\\" + "9.xlsx",index = False)
        m = m-1
        n = n+1
    with pd.ExcelWriter(pathupdate) as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
        path_ELSWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELSW_" + Pro + Date + ".xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)  
        df_ELSWbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1',index = False)
        
        df1.to_excel(writer,sheet_name = rsheetname[0],index = False)
        n = n-1
        if n>0:
            df2.to_excel(writer,sheet_name = rsheetname[1],index = False)
            n = n-1
        if n>0:
            df3.to_excel(writer,sheet_name = rsheetname[2],index = False)
            n = n-1
        if n>0:
            df4.to_excel(writer,sheet_name = rsheetname[3],index = False)
            n = n-1
        if n>0:
            df5.to_excel(writer,sheet_name = rsheetname[4],index = False)
            n = n-1
        if n>0:
            df6.to_excel(writer,sheet_name = rsheetname[5],index = False)
            n = n-1
        if n>0:
            df7.to_excel(writer,sheet_name = rsheetname[6],index = False)
            n = n-1
        if n>0:
            df8.to_excel(writer,sheet_name = rsheetname[7],index = False)
            n = n-1
        if n>0:
            df9.to_excel(writer,sheet_name = rsheetname[8],index = False)
            n = n-1
        if n>0:
            df10.to_excel(writer,sheet_name = rsheetname[9],index = False)
            n = n-1
    writer.save()
else:
    df_ELSW = df_3[(df_3['Function'] == 'EL SW')]
    #path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
    old = pd.read_excel(path_old)
    Nrowold = old.shape[0]

    # 去highlight
    def outhighlight(y):  
        return ['background-color: white'for i in y]
    old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

    dfnew = pd.concat([old,df_ELSW], axis = 0, ignore_index = True, join = "outer")
    
    ## 比较Workflow position是否相同
    d1 = dfnew.to_dict(orient='list')['EC']
    d2 = df_a.to_dict(orient='list')['EC']  ##df_a
    num1 = dfnew.to_dict(orient='list')['Workflow position']
    num2 = df_a.to_dict(orient='list')['Workflow position']
    for i in range(len(d1)):
        for j in range(len(d2)):
            if d1[i] == d2[j]:
                num1[i] = num2[j]            
    dfnew['Workflow position'] = num1
    
    df_ELSWbackup = dfnew
    #df_ELSWbackup = pd.concat([old,df_ELSW], axis = 0, ignore_index = True, join = "outer")
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\ELSW\\" + "ELSW_" + Pro + ".xlsx"
    path_ELSWbackup = r"C" + ":\\Users\\" + "YQIAN5" + "\\Volvo Cars\\" + "#VCCD&VCDQ Commodity ME FA - 11 Program Folder\\" + Pro + "\\08. EC" + "\\backup\\" + "ELSW_" + Pro + Date + ".xlsx"
    #complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
    #complete = len(complete)-1
    #Sum = len(dfnew)-1
    #KPI = complete/Sum

    # 获取想要highlight的行
    light = []
    for i in dfnew.index: 
        if i > Nrowold-1: 
            light.append(i) 

    def highlight(x):  
        return ['background-color: yellow'for i in x]
    
    dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)
    df_ELSWbackup.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(path_ELSWbackup,index = False)

# %%
## old Version

# %%
df_ELSW = df_3[(df_3['Function'] == 'EL SW')]
#path = r"C" + ":\\Users\\" + z + "\\Desktop\\" + "Ext.xlsx"
old = pd.read_excel(r'C:\Users\YQIAN5\Desktop\ELSW\ELSW.xlsx')
Nrowold = old.shape[0]

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
old.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[old.index,])

dfnew = pd.concat([old,df_ELSW], axis = 0, ignore_index = True, join = "outer")
#del dfnew['Unnamed: 0']
#print(dfnew)

pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop\\" + "ELSW\\" + "ELSW.xlsx"
complete = dfnew[(dfnew['Workflow position'] == '09 Completed')|(dfnew['Workflow position'] == '10 Deleted')]
complete = len(complete)-1
Sum = len(dfnew)-1
KPI = complete/Sum

# 获取想要highlight的行
light = []
for i in dfnew.index: 
    if i > Nrowold-1: 
        light.append(i)
print(light)  

def highlight(x):  
    return ['background-color: yellow'for i in x]

dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(pathupdate,index = False)                
print('EL SW的KPI为:',KPI)
# Out:
# []
# EL SW的KPI为: -1.0

# %%
## Demo

df_Book2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\Book2.xlsx")
df_Book1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" + "\\Book1.xlsx")
Nrowold = df_Book1.shape[0]
Book1Allsheet = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" + "\\Book1.xlsx", sheet_name=None)
print(Book1Allsheet)
a = len(Book1Allsheet)
keys = list(Book1Allsheet.keys())

# 去highlight
def outhighlight(y):  
    return ['background-color: white'for i in y]
df_Book1.style.apply(outhighlight,axis=1,subset=pd.IndexSlice[df_Book1.index,])

# 获取sheet名
rsheetname = []
sheetcon = pd.DataFrame()
if a>1:
    for i in range(1,a):
        rsheetname.append(keys[i]) 

    for j in range(0,len(rsheetname)):
        sheetcon = pd.DataFrame(Book1Allsheet[rsheetname[j]])
        del sheetcon['Unnamed: 0']
        sheetcon.to_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + str(j) + ".xlsx")

    # 合并
    pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" + "\\Book1.xlsx"
    dfnew = pd.concat([df_Book1,df_Book2], axis = 0, ignore_index = True, join = "outer")
    del dfnew['Unnamed: 0']
    dfnew.to_excel(pathupdate,index = False)
    
    path = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" #指定文件夹路径
    wj_List = list(os.walk(path))[0][2]       #所有子文件名
    num = len(wj_List)                        #子文件名的个数
    
    m = num - 1
    df1 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "0.xlsx")
    m = m-1
    n = 1
    if m>0:
        df2 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "1.xlsx")
        m = m-1
        n = n+1
    if m>0:
        df3 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "2.xlsx")
        m = m-1
        n = n+1
    if m>0:
        df4 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "3.xlsx")
        m = m-1
        n = n+1
    if m>0:
        df5 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "4.xlsx")
        m = m-1 
        n = n+1
    if m>0:
        df6 = pd.read_excel(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test\\" + "5.xlsx")
        m = m-1
        n = n+1
        
    with pd.ExcelWriter(r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" + "\\Book1.xlsx") as writer:
         # 获取想要highlight的行
        light = []
        for i in dfnew.index: 
            if i > Nrowold-1: 
                light.append(i)  
        def highlight(x):  
            return ['background-color: yellow'for i in x]
        pathupdate = r"C" + ":\\Users\\" + "YQIAN5" + "\\Desktop" + "\\test" + "\\Book1.xlsx"
        dfnew.style.apply(highlight,axis=1,subset=pd.IndexSlice[light,]).to_excel(writer,sheet_name = 'sheet1')  
        del df1['Unnamed: 0']
        df1.to_excel(writer,sheet_name = rsheetname[0])
        n = n-1
        if n>0:
            del df2['Unnamed: 0']
            df2.to_excel(writer,sheet_name = rsheetname[1])
            n = n-1
        if n>0:
            del df3['Unnamed: 0']
            df3.to_excel(writer,sheet_name = rsheetname[2])
            n = n-1
        if n>0:
            del df4['Unnamed: 0']
            df4.to_excel(writer,sheet_name = rsheetname[3])
            n = n-1
        if n>0:
            del df5['Unnamed: 0']
            df5.to_excel(writer,sheet_name = rsheetname[4])
            n = n-1
        if n>0:
            del df6['Unnamed: 0']
            df6.to_excel(writer,sheet_name = rsheetname[5])
            n = n-1
    writer.save()
# Out:
# {'sheet1':     Unnamed: 0   姓名   棉铃  第三个   三个  而未果   删掉  大使馆
# 0            0  多少个   12   45   67   90   34   67
# 1            1   打开   23   67   78   12   45   78
# 2            2   是狗   34   56   89   23   56   89
# 3            3  多少个  999  777  666  555  444  444
# 4            4   打开  888  777  666  555  444  444
# 5            5   是狗  888  777  666  555  444  444
# 6            6  多少个  999  777  666  555  444  444
# 7            7   打开  888  777  666  555  444  444
# 8            8   是狗  888  777  666  555  444  444
# 9            9  多少个  999  777  666  555  444  444
# 10          10   打开  888  777  666  555  444  444
# 11          11   是狗  888  777  666  555  444  444, 'Sheet2':    Unnamed: 0   德国   中国   日本   英国
# 0           0  222  111  333  444, 'Sheet3':    Unnamed: 0   芒果  香蕉  梨子
# 0           0  234  34  56
# 1           1  112  23  12}
